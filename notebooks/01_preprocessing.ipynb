# %% [markdown]
# <a href="https://colab.research.google.com/github/FHerror404/BDSL-Sign-to-Text/blob/main/notebooks/01_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01_preprocessing.ipynb
# Thesis: Bangla Sign Language
# Step: Dataset preprocessing

from google.colab import drive
drive.mount('/content/drive')

print("Colab + Drive connected successfully")
# Out:
# Mounted at /content/drive
# Colab + Drive connected successfully
